# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyani-asekar/ot_practicals/blob/main/prac1_ot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
x = sp.symbols('x')
f = x**3 - 6*x**2 + 9*x + 1
f_prime = sp.diff(f, x)
critical_points = sp.solve(f_prime, x)
print("Critical points:", critical_points)
f_double_prime = sp.diff(f_prime, x)
for point in critical_points:
    second_derivative = f_double_prime.subs(x, point)
    function_value = f.subs(x, point)

    if second_derivative > 0:
        print("Local Minimum at:", (point, function_value))
    elif second_derivative < 0:
        print("Local Maximum at:", (point, function_value))
    else:
        print("Second derivative test is inconclusive at:", point)
